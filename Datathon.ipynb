# %% [markdown]
# <a href="https://colab.research.google.com/github/Monjolaoluwa-Runsewe/DFGRETRY/blob/jessica-branch/Datathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install git
# Out:
# ERROR: Could not find a version that satisfies the requirement git (from versions: none)
# ERROR: No matching distribution found for git
